# %% [markdown]
# from huggingface_hub import login
# from huggingface_hub import hf_hub_download
# from huggingface_hub import list_repo_files
#
# # This will prompt you to enter your Hugging Face token
# # login(token="")

# %% [markdown]
# import sys
# from whisper import _download, _MODELS
#
# models = ["turbo"]
#
# for model in models:
#     _download(_MODELS[model], "C:/Users/wengz/Desktop/model_weights/openai/whisper", False)

# %% [markdown]
# # Replace 'model_id' with the ID of the model you want to download
# model_id = "openai/whisper-large-v3"
#
# # List all files in the repository
# files = list_repo_files(repo_id=model_id)
#
# # Download each file
# local_dir = "C:/Users/wengz/Desktop/model_weights/openai/whisper-large-v3"
# for file in files:
#     file_path = hf_hub_download(repo_id=model_id, filename=file,local_dir=local_dir)
#     print(f"Downloaded {file} to {file_path}")

# %% [markdown]
# # Replace 'model_id' with the ID of the model you want to download
# model_id = "pyannote/segmentation-3.0"
#
# # List all files in the repository
# files = list_repo_files(repo_id=model_id)
#
# # Download each file
# local_dir = "C:/Users/wengz/Desktop/model_weights/pyannote/speaker-diarization-3.1"
# for file in files:
#     file_path = hf_hub_download(repo_id=model_id, filename=file,local_dir=local_dir)
#     print(f"Downloaded {file} to {file_path}")

# %%
import whisper

# Load Whisper model (base, small, medium, large models available)
model = whisper.load_model("C:/Users/wengz/Desktop/model_weights/openai/whisper/large-v3-turbo.pt")

# Transcribe the audio
result = model.transcribe("./files/Council Meeting - July 26, 2022.mp3")

# This will give you the transcription and timestamps for each segment
transcription = result['text']
segments = result['segments']
# Out:
# c:\Users\wengz\miniforge3\envs\ds_gpu\Lib\site-packages\whisper\__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
from pyannote.audio import Model
local_dir = "C:/Users/wengz/Desktop/model_weights/pyannote/speaker-diarization-3.1/pytorch_model.bin"
model = Model.from_pretrained(local_dir)

# %%
from pyannote.audio.pipelines import VoiceActivityDetection
pipeline = VoiceActivityDetection(segmentation=model)
HYPER_PARAMETERS = {
  # remove speech regions shorter than that many seconds.
  "min_duration_on": 0.0,
  # fill non-speech regions shorter than that many seconds.
  "min_duration_off": 0.0
}
pipeline.instantiate(HYPER_PARAMETERS)

# %%
from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained(
    "pyannote/speaker-diarization-3.1",
    use_auth_token="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")

# %%
from pyannote.audio import Pipeline
local_dir = "C:/Users/wengz/Desktop/model_weights/pyannote/speaker-diarization-3.1/config.yaml"
pipeline = Pipeline.from_pretrained(local_dir)

# %%
# Apply the pipeline to an audio file
diarization = pipeline("./files/Council Meeting - July 26, 2022.mp3")
# Out:
# c:\Users\wengz\miniforge3\envs\ds_gpu\Lib\site-packages\pyannote\audio\models\blocks\pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1808.)
#   std = sequences.std(dim=-1, correction=1)
# c:\Users\wengz\miniforge3\envs\ds_gpu\Lib\site-packages\torchaudio\_backend\soundfile_backend.py:71: UserWarning: The MPEG_LAYER_III subtype is unknown to TorchAudio. As a result, the bits_per_sample attribute will be set to 0. If you are seeing this warning, please report by opening an issue on github (after checking for existing/closed ones). You may otherwise ignore this warning.
#   warnings.warn(
# ...

# %%
# Unpack three values from itertracks: segment, track, and speaker
list_id = []
for segment, _, speaker in diarization.itertracks(yield_label=True):
    print(f"Speaker {speaker} from {segment.start:.1f}s to {segment.end:.1f}s")
    list_id.append(id)
# Out:
# Speaker SPEAKER_01 from 0.6s to 4.0s
# Speaker SPEAKER_01 from 5.0s to 6.5s
# Speaker SPEAKER_01 from 6.9s to 15.1s
# Speaker SPEAKER_00 from 17.2s to 21.3s
# Speaker SPEAKER_01 from 22.7s to 25.7s
# Speaker SPEAKER_01 from 27.6s to 29.7s
# Speaker SPEAKER_01 from 31.0s to 33.3s
# Speaker SPEAKER_01 from 34.3s to 41.0s
# Speaker SPEAKER_01 from 42.2s to 43.2s
# Speaker SPEAKER_01 from 44.9s to 45.3s
# Speaker SPEAKER_01 from 45.6s to 46.4s
# Speaker SPEAKER_01 from 46.8s to 67.0s
# Speaker SPEAKER_01 from 67.8s to 73.1s
# Speaker SPEAKER_01 from 73.6s to 78.7s
# Speaker SPEAKER_01 from 79.3s to 84.5s
# Speaker SPEAKER_01 from 88.9s to 93.6s
# Speaker SPEAKER_01 from 94.2s to 95.8s
# Speaker SPEAKER_00 from 97.2s to 98.0s
# Speaker SPEAKER_00 from 98.4s to 103.1s
# Speaker SPEAKER_00 from 103.7s to 107.0s
# Speaker SPEAKER_01 from 108.3s to 110.9s
# Speaker SPEAKER_01 from 112.7s to 113.6s
# Speaker SPEAKER_01 from 114.4s to 115.4s
# Speaker SPEAKER_01 from 117.3s to 125.4s
# ...

# %%
# Function to align transcription with speakers
def align_transcription_with_speakers(whisper_segments, diarization_result):
    combined_output = []
    
    for whisper_segment in whisper_segments:
        whisper_start = whisper_segment['start']
        whisper_end = whisper_segment['end']
        whisper_text = whisper_segment['text']
        
        # Find which speaker was active during the whisper segment
        for segment, _, speaker in diarization.itertracks(yield_label=True):
            speaker_start = segment.start
            speaker_end = segment.end
            
            # Check if Whisper segment overlaps with this speaker segment
            if speaker_start <= whisper_start <= speaker_end or speaker_start <= whisper_end <= speaker_end:
                combined_output.append({
                    "speaker": speaker,
                    "text": whisper_text,
                    "start": whisper_start,
                    "end": whisper_end
                })
    
    return combined_output

# %%
# Align Whisper transcription with speaker diarization
aligned_transcription = align_transcription_with_speakers(result['segments'], diarization)

# %%
# Display the aligned transcription with speakers
for segment in aligned_transcription:
    print(f"Speaker {segment['speaker']} from {segment['start']:.2f}s to {segment['end']:.2f}s: {segment['text']}")
# Out:
# Speaker SPEAKER_01 from 4.00s to 8.00s:  Before we move forward with the approval of the,
# Speaker SPEAKER_01 from 8.00s to 10.00s:  or maybe I'll do the approval of the agenda first.
# Speaker SPEAKER_01 from 10.00s to 13.00s:  Can I have a mover and seconder for the approval of the agenda, please?
# Speaker SPEAKER_01 from 13.00s to 15.00s:  Councillor Rellke, Councillor Fuell.
# Speaker SPEAKER_01 from 15.00s to 21.00s:  Be resolved that the agenda for July 26th council meeting be approved.
# Speaker SPEAKER_00 from 15.00s to 21.00s:  Be resolved that the agenda for July 26th council meeting be approved.
# Speaker SPEAKER_00 from 21.00s to 25.00s:  Thank you. Is there any additions from council?
# Speaker SPEAKER_01 from 21.00s to 25.00s:  Thank you. Is there any additions from council?
# Speaker SPEAKER_01 from 25.00s to 29.00s:  I have SHHI appointment.
# Speaker SPEAKER_01 from 25.00s to 29.00s:  I have SHHI appointment.
# ...
